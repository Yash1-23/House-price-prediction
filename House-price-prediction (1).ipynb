# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import mpl_toolkits
# %matplotlib inline

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608      1530.0              0      2009             0    98103  47.6993
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df = df.drop(columns=['sqft_above'])

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  zipcode        21613 non-null  int64
#  16  lat            21613 non-null  float64
# ...

# %%
df['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=df.lat.values, y=df.long.values, size=10)
plt.ylabel('Longitude',fontsize=12)
plt.xlabel('Latitude',fontsize=12)
plt.show()
plt1=plt()
sns.despine
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[157], line 6
#       4 plt.xlabel('Latitude',fontsize=12)
#       5 plt.show()
# ----> 6 plt1=plt()
#       7 sns.despine
#
# TypeError: 'module' object is not callable

# %%
plt.scatter(df.price,df.long)
plt.title("Price vs location of the area")
# Out:
# Text(0.5, 1.0, 'Price vs location of the area')

# %%
plt.scatter(df.price,df.lat)
plt.xlabel('Price')
plt.ylabel('Latitude')
plt.title('Latitude vs Price')
# Out:
# Text(0.5, 1.0, 'Latitude vs Price')

# %%
plt.scatter(df.bedrooms,df.price)
plt.title("Bedrooms vs Price")
plt.xlabel('bedrooms')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter((df['sqft_living']+df['sqft_basement']),df['price'])

# %%
plt.scatter(df.waterfront,df.price)
plt.title("Waterfront vs Price (0 = no waterfront)")
# Out:
# Text(0.5, 1.0, 'Waterfront vs Price (0 = no waterfront)')

# %%
train1= df.drop(['id','price'],axis=1)

# %%
train1.head()
# Out:
#               date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013T000000         3       1.00         1180      5650     1.0
# 1  20141209T000000         3       2.25         2570      7242     2.0
# 2  20150225T000000         2       1.00          770     10000     1.0
# 3  20141209T000000         4       3.00         1960      5000     1.0
# 4  20150218T000000         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3      7              0      1955             0
# 1           0     0          3      7            400      1951          1991
# 2           0     0          3      6              0      1933             0
# 3           0     0          5      7            910      1965             0
# 4           0     0          3      8              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df.floors.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='floors'>

# %%
plt.scatter(df.floors,df.price)

# %%
plt.scatter(df.condition,df.price)

# %%
plt.scatter(df.zipcode,df.price)
plt.title("Which is the pricey location by zipcode")
# Out:
# Text(0.5, 1.0, 'Which is the pricey location by zipcode')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
labels = df['price']
conv_dates = [1 if values  == 2014 else 0 for values in df.date]
df['date'] = conv_dates
train1 = df.drop(['id', 'price'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(train1, labels, test_size=0.12, random_state=42)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(X_test,y_test)
# Out:
# 0.6786349972803678

# %%
from sklearn  import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5,min_samples_split=2,
                                        learning_rate = 0.1, loss='squared_error')

# %%
clf.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=400)

# %%
clf.score(X_test,y_test)
# Out:
# 0.9005222648216727

# %%
params = {
    'n_estimators': 100  # Example value; adjust as needed
}

# %%
t_sc = np.zeros((params['n_estimators']),dtype=np.float64)

# %%
y_pred = reg.predict(X_test)

# %%
# Remove the 'sqft_above' column from both X_train and X_test if it was dropped
X_train = X_train.drop(columns=['sqft_above'], errors='ignore')
X_test = X_test.drop(columns=['sqft_above'], errors='ignore')

# Check the columns to ensure they match
print("Training columns:", X_train.columns)
print("Testing columns:", X_test.columns)
# Out:
# Training columns: Index(['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_basement', 'yr_built',
#        'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15'],
#       dtype='object')
# Testing columns: Index(['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_basement', 'yr_built',
#        'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15'],
#       dtype='object')

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# Initialize and fit the model
clf = GradientBoostingRegressor(n_estimators=100, loss='squared_error')
clf.fit(X_train, y_train)

# Initialize an array to store MSE values
t_sc = np.zeros(clf.n_estimators, dtype=np.float64)

# Calculate MSE for staged predictions
for i, y_pred in enumerate(clf.staged_predict(X_test)):
    t_sc[i] = mean_squared_error(y_test, y_pred)

print(t_sc)
# Out:
# [1.29059876e+11 1.15253138e+11 1.02994540e+11 9.33108626e+10
#  8.55605026e+10 7.80033746e+10 7.20147292e+10 6.64015379e+10
#  6.20217828e+10 5.87755159e+10 5.59484159e+10 5.32004150e+10
#  5.05957529e+10 4.82972980e+10 4.61033380e+10 4.39401736e+10
#  4.21739140e+10 4.06539027e+10 3.90210314e+10 3.77838210e+10
#  3.66599161e+10 3.57420012e+10 3.46421218e+10 3.38044309e+10
#  3.29301182e+10 3.22593179e+10 3.16928377e+10 3.11990665e+10
#  3.06002077e+10 2.99219070e+10 2.92225558e+10 2.86621194e+10
#  2.81821365e+10 2.77154647e+10 2.74394401e+10 2.70598697e+10
#  2.67564150e+10 2.64425884e+10 2.61533154e+10 2.57421556e+10
#  2.56045576e+10 2.53543470e+10 2.51215618e+10 2.49272636e+10
#  2.46414436e+10 2.44805165e+10 2.42999417e+10 2.40295298e+10
#  2.38343947e+10 2.36142765e+10 2.34880969e+10 2.34123455e+10
#  2.32229449e+10 2.31417952e+10 2.30324405e+10 2.29441418e+10
#  2.27679483e+10 2.26876979e+10 2.26023937e+10 2.24649089e+10
# ...

# %%
testsc  = np.arange((params['n_estimators']))+1

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(testsc,clf.train_score_, 'b-',label = 'set dev train')
plt.plot(testsc,t_sc, 'r-',label = 'set dev test')

# %%
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
pca.fit_transform(scale(train1))
# Out:
# array([[-2.58354961, -0.01711553, -0.25440791, ..., -0.40839828,
#          0.01966101,  0.        ],
#        [-0.48438945,  1.7096755 , -0.6804804 , ...,  0.5350027 ,
#          0.65629676,  0.        ],
#        [-2.27563978, -0.60458094,  0.36745081, ...,  1.28338034,
#         -0.41196694,  0.        ],
#        ...,
#        [-2.25679855, -1.07600012, -1.43625137, ...,  0.19559674,
#          0.38707996, -0.        ],
#        [ 0.45113467, -1.88859592, -1.09682622, ..., -0.5661675 ,
#         -0.23105314,  0.        ],
#        [-2.27011813, -1.06049764, -1.44513849, ...,  0.18778099,
#          0.38203177, -0.        ]])
